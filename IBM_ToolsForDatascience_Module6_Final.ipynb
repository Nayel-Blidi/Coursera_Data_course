# %% [markdown]
# # Tools for Data Science : Module 6 Final

# %% [markdown]
# ### Exercise 1 - Create a Jupyter notebook file

# %% [markdown]
# ### Exercise 2 - Create a markdown cell with the title of the notebook :
# cf above

# %% [markdown]
# ### Exercise 3 - Create a markdown cell for an introduction :
# This is an introduction to the data science tools. These tools refer to all the programming languages, libraries, services and website or organisations that are useful everyday to a data scientist in his work.

# %% [markdown]
# ### Exercise 4 - Create a markdown cell to list data science languages :
# Some popular data science languages are :
# 1. Python : the open source language mostly used in data science, especially for AI development
# 2. R : a more statistical oriented language, that features powerful data analysis and data visualization libraries.
# 3. SQL : a request based language used to manage databases.
# 4. C++ : a development language, useful for exporting programs as softwares.

# %% [markdown]
# ### Exercise 5 - Create a markdown cell to list data science libraries :
# Data science libraries are different for every languages, here is a short common list :
#
# #### Python :
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 3. Scikit-learn
# 4. Tensorflow
#
# #### R :
# 1. ggplot
# 2. GGally
# 3. dplyr

# %% [markdown]
# ### Exercise 6 - Create a markdown cell with a table of Data Science tools :
# |Languages|Libraries|
# |---|---|
# |Python|Numpy, Pandas|
# |R|ggplot2|

# %% [markdown]
# ### Exercise 7 - Create a markdown cell introducing arithmetic expression examples :
# x = 3 <br>
# y = 4 <br>
# x + y = 7

# %% [markdown]
# ### Exercise 8 - Create a code cell to multiply and add numbers :

# %%
x = 3
y = 4
x_times_y = x * y
x_plus_y = x + y
print(x_times_y, x_plus_y)
# Out:
# 12 7

# %% [markdown]
# ### Exercise 9 - Create a code cell to convert minutes to hours :

# %%
minutes = 400
hours = minutes // 60
hours = hours + round((minutes % 60)/60, 2)
print(minutes, "minutes are equal to", hours, "hours")
# Out:
# 400 minutes are equal to 6.67 hours

# %% [markdown]
# ### Exercise 10 -Insert a markdown cell to list Objectives :
# I'm guessing this refers to the list option in a markdown such as :
# 1. Change the multiply and add numbers code to two distinct functions
# 2. Change the minutes to hours code to two distinct functions

# %% [markdown]
# ### Exercise 11 - Create a markdown cell to indicate the Author’s name :
# Very important, my name is : **Nayel BLIDI**

# %% [markdown]
# ### Exercise 12 - Share your notebook through GitHub :
# Here is the [link](https://github.com/Nayel-Blidi/Coursera_Data_course.git) to my Git repository.

# %% [markdown]
# ### Exercise 13 - Take a screenshot of the first page of the notebook :

# %% [markdown]
# ![image.png](attachment:image.png)
